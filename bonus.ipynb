# %% [markdown]
# ## Bonus on Google Cloud

# %%
import pyspark
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import *
import pandas as pd

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("fifa") \
    .config("spark.jars", "/usr/lib/spark/jars/postgresql-42.2.20.jar") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/14 19:37:48 INFO SparkEnv: Registering MapOutputTracker
# 24/11/14 19:37:48 INFO SparkEnv: Registering BlockManagerMaster
# 24/11/14 19:37:49 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 24/11/14 19:37:49 INFO SparkEnv: Registering OutputCommitCoordinator

# %%
ls /usr/lib/spark/jars/postgresql-42.2.20.jar
# Out:
# /usr/lib/spark/jars/postgresql-42.2.20.jar

# %%
# Read one of data to get the headers
data_sample = pd.read_csv("gs://myspark-bucket/data/players_15.csv", nrows=2)
column_names = list(data_sample.columns)

# %%
def infer_sql_type(dtype):
    """Map pandas data type to PostgreSQL"""
    if pd.api.types.is_integer_dtype(dtype):
        return "INT"
    elif pd.api.types.is_float_dtype(dtype):
        return "FLOAT"
    elif pd.api.types.is_bool_dtype(dtype):
        return "BOOLEAN"
    else:
        return "VARCHAR"

# Infer data type for each column in Postgres
column_types = {col: infer_sql_type(dtype) for col, dtype in zip(data_sample.columns, data_sample.dtypes)}

# Create a new column of year
column_types['year'] = "INT"

# Create a new column of gender
column_types['gender'] = "VARCHAR"

# Print the crrent result
for col, col_type in column_types.items():
    print(f"{col}: {col_type}")
# Out:
# sofifa_id: INT
# player_url: VARCHAR
# short_name: VARCHAR
# long_name: VARCHAR
# player_positions: VARCHAR
# overall: INT
# potential: INT
# value_eur: FLOAT
# wage_eur: FLOAT
# age: INT
# dob: VARCHAR
# height_cm: INT
# weight_kg: INT
# club_team_id: FLOAT
# club_name: VARCHAR
# league_name: VARCHAR
# league_level: INT
# club_position: VARCHAR
# club_jersey_number: INT
# club_loaned_from: FLOAT
# club_joined: VARCHAR
# club_contract_valid_until: INT
# nationality_id: INT
# nationality_name: VARCHAR
# nation_team_id: FLOAT
# nation_position: VARCHAR
# nation_jersey_number: INT
# preferred_foot: VARCHAR
# weak_foot: INT
# skill_moves: INT
# international_reputation: INT
# work_rate: VARCHAR
# body_type: VARCHAR
# real_face: VARCHAR
# release_clause_eur: FLOAT
# player_tags: VARCHAR
# player_traits: VARCHAR
# pace: INT
# shooting: INT
# passing: INT
# dribbling: INT
# defending: INT
# physic: INT
# attacking_crossing: INT
# attacking_finishing: INT
# attacking_heading_accuracy: INT
# attacking_short_passing: INT
# attacking_volleys: INT
# skill_dribbling: INT
# skill_curve: INT
# skill_fk_accuracy: INT
# skill_long_passing: INT
# skill_ball_control: INT
# movement_acceleration: INT
# movement_sprint_speed: INT
# movement_agility: INT
# movement_reactions: INT
# movement_balance: INT
# power_shot_power: INT
# power_jumping: INT
# power_stamina: INT
# power_strength: INT
# power_long_shots: INT
# mentality_aggression: INT
# mentality_interceptions: INT
# mentality_positioning: INT
# mentality_vision: INT
# mentality_penalties: INT
# mentality_composure: FLOAT
# defending_marking_awareness: INT
# defending_standing_tackle: INT
# defending_sliding_tackle: INT
# goalkeeping_diving: INT
# goalkeeping_handling: INT
# goalkeeping_kicking: INT
# goalkeeping_positioning: INT
# goalkeeping_reflexes: INT
# goalkeeping_speed: FLOAT
# ls: VARCHAR
# st: VARCHAR
# rs: VARCHAR
# lw: VARCHAR
# lf: VARCHAR
# cf: VARCHAR
# rf: VARCHAR
# rw: VARCHAR
# lam: VARCHAR
# cam: VARCHAR
# ram: VARCHAR
# lm: VARCHAR
# lcm: VARCHAR
# cm: VARCHAR
# rcm: VARCHAR
# rm: VARCHAR
# lwb: VARCHAR
# ldm: VARCHAR
# cdm: VARCHAR
# rdm: VARCHAR
# rwb: VARCHAR
# lb: VARCHAR
# lcb: VARCHAR
# cb: VARCHAR
# rcb: VARCHAR
# rb: VARCHAR
# gk: VARCHAR
# player_face_url: VARCHAR
# club_logo_url: VARCHAR
# club_flag_url: VARCHAR
# nation_logo_url: VARCHAR
# nation_flag_url: VARCHAR
# year: INT
# gender: VARCHAR

# %%
#Create a new table names "fifa"
table = "dataset" 
columns = ",\n    ".join([f'"{col}" {dtype}' for col, dtype in column_types.items()])

create_table = f"""
CREATE SCHEMA fifa;
CREATE TABLE fifa.{table} (
    id SERIAL PRIMARY KEY,
    {columns}
);
"""

print(create_table)
# Out:
# CREATE SCHEMA fifa;
# CREATE TABLE fifa.dataset (
#     id SERIAL PRIMARY KEY,
#     "sofifa_id" INT,
#     "player_url" VARCHAR,
#     "short_name" VARCHAR,
#     "long_name" VARCHAR,
#     "player_positions" VARCHAR,
#     "overall" INT,
#     "potential" INT,
#     "value_eur" FLOAT,
#     "wage_eur" FLOAT,
#     "age" INT,
#     "dob" VARCHAR,
#     "height_cm" INT,
#     "weight_kg" INT,
#     "club_team_id" FLOAT,
#     "club_name" VARCHAR,
#     "league_name" VARCHAR,
#     "league_level" INT,
#     "club_position" VARCHAR,
#     "club_jersey_number" INT,
#     "club_loaned_from" FLOAT,
#     "club_joined" VARCHAR,
#     "club_contract_valid_until" INT,
#     "nationality_id" INT,
#     "nationality_name" VARCHAR,
#     "nation_team_id" FLOAT,
#     "nation_position" VARCHAR,
#     "nation_jersey_number" INT,
#     "preferred_foot" VARCHAR,
#     "weak_foot" INT,
#     "skill_moves" INT,
#     "international_reputation" INT,
#     "work_rate" VARCHAR,
#     "body_type" VARCHAR,
#     "real_face" VARCHAR,
#     "release_clause_eur" FLOAT,
#     "player_tags" VARCHAR,
#     "player_traits" VARCHAR,
#     "pace" INT,
#     "shooting" INT,
#     "passing" INT,
#     "dribbling" INT,
#     "defending" INT,
#     "physic" INT,
#     "attacking_crossing" INT,
#     "attacking_finishing" INT,
#     "attacking_heading_accuracy" INT,
#     "attacking_short_passing" INT,
#     "attacking_volleys" INT,
#     "skill_dribbling" INT,
#     "skill_curve" INT,
#     "skill_fk_accuracy" INT,
#     "skill_long_passing" INT,
#     "skill_ball_control" INT,
#     "movement_acceleration" INT,
#     "movement_sprint_speed" INT,
#     "movement_agility" INT,
#     "movement_reactions" INT,
#     "movement_balance" INT,
#     "power_shot_power" INT,
#     "power_jumping" INT,
#     "power_stamina" INT,
#     "power_strength" INT,
#     "power_long_shots" INT,
#     "mentality_aggression" INT,
#     "mentality_interceptions" INT,
#     "mentality_positioning" INT,
#     "mentality_vision" INT,
#     "mentality_penalties" INT,
#     "mentality_composure" FLOAT,
#     "defending_marking_awareness" INT,
#     "defending_standing_tackle" INT,
#     "defending_sliding_tackle" INT,
#     "goalkeeping_diving" INT,
#     "goalkeeping_handling" INT,
#     "goalkeeping_kicking" INT,
#     "goalkeeping_positioning" INT,
#     "goalkeeping_reflexes" INT,
#     "goalkeeping_speed" FLOAT,
#     "ls" VARCHAR,
#     "st" VARCHAR,
#     "rs" VARCHAR,
#     "lw" VARCHAR,
#     "lf" VARCHAR,
#     "cf" VARCHAR,
#     "rf" VARCHAR,
#     "rw" VARCHAR,
#     "lam" VARCHAR,
#     "cam" VARCHAR,
#     "ram" VARCHAR,
#     "lm" VARCHAR,
#     "lcm" VARCHAR,
#     "cm" VARCHAR,
#     "rcm" VARCHAR,
#     "rm" VARCHAR,
#     "lwb" VARCHAR,
#     "ldm" VARCHAR,
#     "cdm" VARCHAR,
#     "rdm" VARCHAR,
#     "rwb" VARCHAR,
#     "lb" VARCHAR,
#     "lcb" VARCHAR,
#     "cb" VARCHAR,
#     "rcb" VARCHAR,
#     "rb" VARCHAR,
#     "gk" VARCHAR,
#     "player_face_url" VARCHAR,
#     "club_logo_url" VARCHAR,
#     "club_flag_url" VARCHAR,
#     "nation_logo_url" VARCHAR,
#     "nation_flag_url" VARCHAR,
#     "year" INT,
#     "gender" VARCHAR
# );

# %%
# Read male data
total_data = spark.read.csv('gs://myspark-bucket/data/players_15.csv', header=True, inferSchema=True)
total_data = total_data.withColumn("year", lit(2015))
total_data = total_data.withColumn("gender", lit("male"))

for i in range(16,17):
    data = spark.read.csv(f"gs://myspark-bucket/data/players_{i}.csv",header=True, inferSchema=True)
    data = data.toDF(*column_names)
    data = data.withColumn("year", lit(2000+i))
    data = data.withColumn("gender", lit("male"))
    total_data = total_data.union(data)
print("total male players: ",total_data.count())

#Read female data
for i in range(16,23):
    data = spark.read.csv(f'gs://myspark-bucket/data/players_{i}.csv',header=True, inferSchema=True)
    data = data.toDF(*column_names)
    data = data.withColumn("year", lit(2000+i))
    data = data.withColumn("gender", lit("female"))
    total_data = total_data.union(data)
    
print("total female players: ",total_data.count())   

# Ensure every record can be uniquely identified in the database table
print("total unique records: ",total_data.distinct().count())
# Out:
# total male players:  31778
# total female players:  157702
# 24/11/14 19:38:56 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 26:=============================>                            (2 + 2) / 4]
# total unique records:  157702

# %%
# Ingest data to PostgresDB
postgres_url = "jdbc:postgresql://172.25.240.4:5432/postgres"
postgres_properties = {
    "user": "postgres",
    "password": "Liujiayi",
    "driver": "org.postgresql.Driver"
}

# Write data to DB
total_data.write \
    .option("driver", "org.postgresql.Driver")\
    .jdbc(url=postgres_url, table="fifa", mode="overwrite", properties=postgres_properties)

# Read data from DB
data_postgres = spark.read \
    .jdbc(url=postgres_url, table="fifa", properties=postgres_properties)

data_postgres.printSchema()
data_postgres.show(5, vertical=True)
# Out:
# root
#  |-- sofifa_id: integer (nullable = true)
#  |-- player_url: string (nullable = true)
#  |-- short_name: string (nullable = true)
#  |-- long_name: string (nullable = true)
#  |-- player_positions: string (nullable = true)
#  |-- overall: integer (nullable = true)
#  |-- potential: integer (nullable = true)
#  |-- value_eur: double (nullable = true)
#  |-- wage_eur: double (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- dob: date (nullable = true)
#  |-- height_cm: integer (nullable = true)
#  |-- weight_kg: integer (nullable = true)
#  |-- club_team_id: double (nullable = true)
#  |-- club_name: string (nullable = true)
#  |-- league_name: string (nullable = true)
#  |-- league_level: integer (nullable = true)
#  |-- club_position: string (nullable = true)
#  |-- club_jersey_number: integer (nullable = true)
#  |-- club_loaned_from: string (nullable = true)
#  |-- club_joined: date (nullable = true)
#  |-- club_contract_valid_until: integer (nullable = true)
#  |-- nationality_id: integer (nullable = true)
#  |-- nationality_name: string (nullable = true)
#  |-- nation_team_id: double (nullable = true)
#  |-- nation_position: string (nullable = true)
#  |-- nation_jersey_number: integer (nullable = true)
#  |-- preferred_foot: string (nullable = true)
#  |-- weak_foot: integer (nullable = true)
#  |-- skill_moves: integer (nullable = true)
#  |-- international_reputation: integer (nullable = true)
#  |-- work_rate: string (nullable = true)
#  |-- body_type: string (nullable = true)
#  |-- real_face: string (nullable = true)
#  |-- release_clause_eur: string (nullable = true)
#  |-- player_tags: string (nullable = true)
#  |-- player_traits: string (nullable = true)
#  |-- pace: integer (nullable = true)
#  |-- shooting: integer (nullable = true)
#  |-- passing: integer (nullable = true)
#  |-- dribbling: integer (nullable = true)
#  |-- defending: integer (nullable = true)
#  |-- physic: integer (nullable = true)
#  |-- attacking_crossing: integer (nullable = true)
#  |-- attacking_finishing: integer (nullable = true)
#  |-- attacking_heading_accuracy: integer (nullable = true)
#  |-- attacking_short_passing: integer (nullable = true)
#  |-- attacking_volleys: integer (nullable = true)
#  |-- skill_dribbling: integer (nullable = true)
#  |-- skill_curve: integer (nullable = true)
#  |-- skill_fk_accuracy: integer (nullable = true)
#  |-- skill_long_passing: integer (nullable = true)
#  |-- skill_ball_control: integer (nullable = true)
#  |-- movement_acceleration: integer (nullable = true)
#  |-- movement_sprint_speed: integer (nullable = true)
#  |-- movement_agility: integer (nullable = true)
#  |-- movement_reactions: integer (nullable = true)
#  |-- movement_balance: integer (nullable = true)
#  |-- power_shot_power: integer (nullable = true)
#  |-- power_jumping: integer (nullable = true)
#  |-- power_stamina: integer (nullable = true)
#  |-- power_strength: integer (nullable = true)
#  |-- power_long_shots: integer (nullable = true)
#  |-- mentality_aggression: integer (nullable = true)
#  |-- mentality_interceptions: integer (nullable = true)
#  |-- mentality_positioning: integer (nullable = true)
#  |-- mentality_vision: integer (nullable = true)
#  |-- mentality_penalties: integer (nullable = true)
#  |-- mentality_composure: string (nullable = true)
#  |-- defending_marking_awareness: integer (nullable = true)
#  |-- defending_standing_tackle: integer (nullable = true)
#  |-- defending_sliding_tackle: integer (nullable = true)
#  |-- goalkeeping_diving: integer (nullable = true)
#  |-- goalkeeping_handling: integer (nullable = true)
#  |-- goalkeeping_kicking: integer (nullable = true)
#  |-- goalkeeping_positioning: integer (nullable = true)
#  |-- goalkeeping_reflexes: integer (nullable = true)
#  |-- goalkeeping_speed: integer (nullable = true)
#  |-- ls: string (nullable = true)
#  |-- st: string (nullable = true)
#  |-- rs: string (nullable = true)
#  |-- lw: string (nullable = true)
#  |-- lf: string (nullable = true)
#  |-- cf: string (nullable = true)
#  |-- rf: string (nullable = true)
#  |-- rw: string (nullable = true)
#  |-- lam: string (nullable = true)
#  |-- cam: string (nullable = true)
#  |-- ram: string (nullable = true)
#  |-- lm: string (nullable = true)
#  |-- lcm: string (nullable = true)
#  |-- cm: string (nullable = true)
#  |-- rcm: string (nullable = true)
#  |-- rm: string (nullable = true)
#  |-- lwb: string (nullable = true)
#  |-- ldm: string (nullable = true)
#  |-- cdm: string (nullable = true)
#  |-- rdm: string (nullable = true)
#  |-- rwb: string (nullable = true)
#  |-- lb: string (nullable = true)
#  |-- lcb: string (nullable = true)
#  |-- cb: string (nullable = true)
#  |-- rcb: string (nullable = true)
#  |-- rb: string (nullable = true)
#  |-- gk: string (nullable = true)
#  |-- player_face_url: string (nullable = true)
#  |-- club_logo_url: string (nullable = true)
#  |-- club_flag_url: string (nullable = true)
#  |-- nation_logo_url: string (nullable = true)
#  |-- nation_flag_url: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- gender: string (nullable = true)
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 215085
#  player_url                  | https://sofifa.co...
#  short_name                  | R. Naranjo
#  long_name                   | Rodrigo Felipe Na...
#  player_positions            | GK
#  overall                     | 66
#  potential                   | 66
#  value_eur                   | 475000.0
#  wage_eur                    | 4000.0
#  age                         | 34
#  dob                         | 1979-08-30
#  height_cm                   | 192
#  weight_kg                   | 89
#  club_team_id                | 112531.0
#  club_name                   | Deportes Iquique
#  league_name                 | Chilian Campeonat...
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 1
#  club_loaned_from            | NULL
#  club_joined                 | 2008-01-01
#  club_contract_valid_until   | 2020
#  nationality_id              | 55
#  nationality_name            | Chile
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | NULL
#  player_tags                 | NULL
#  player_traits               | NULL
#  pace                        | NULL
#  shooting                    | NULL
#  passing                     | NULL
#  dribbling                   | NULL
#  defending                   | NULL
#  physic                      | NULL
#  attacking_crossing          | 25
#  attacking_finishing         | 25
#  attacking_heading_accuracy  | 25
#  attacking_short_passing     | 20
#  attacking_volleys           | 25
#  skill_dribbling             | 25
#  skill_curve                 | 25
#  skill_fk_accuracy           | 25
#  skill_long_passing          | 25
#  skill_ball_control          | 25
#  movement_acceleration       | 41
#  movement_sprint_speed       | 43
#  movement_agility            | 37
#  movement_reactions          | 67
#  movement_balance            | 40
#  power_shot_power            | 25
#  power_jumping               | 66
#  power_stamina               | 24
#  power_strength              | 83
#  power_long_shots            | 25
#  mentality_aggression        | 25
#  mentality_interceptions     | 25
#  mentality_positioning       | 25
#  mentality_vision            | 25
#  mentality_penalties         | 20
#  mentality_composure         | NULL
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 25
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 69
#  goalkeeping_handling        | 67
#  goalkeeping_kicking         | 63
#  goalkeeping_positioning     | 64
#  goalkeeping_reflexes        | 65
#  goalkeeping_speed           | 42
#  ls                          | 32
#  st                          | 32
#  rs                          | 32
#  lw                          | 30
#  lf                          | 30
#  cf                          | 30
#  rf                          | 30
#  rw                          | 30
#  lam                         | 29
#  cam                         | 29
#  ram                         | 29
#  lm                          | 29
#  lcm                         | 28
#  cm                          | 28
#  rcm                         | 28
#  rm                          | 29
#  lwb                         | 29
#  ldm                         | 32
#  cdm                         | 32
#  rdm                         | 32
#  rwb                         | 29
#  lb                          | 29
#  lcb                         | 34
#  cb                          | 34
#  rcb                         | 34
#  rb                          | 29
#  gk                          | 66
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  gender                      | male
# -RECORD 1-------------------------------------------
#  sofifa_id                   | 215109
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Navarro
#  long_name                   | Leandro Alexis Na...
#  player_positions            | CM, RM
#  overall                     | 66
#  potential                   | 72
#  value_eur                   | 600000.0
#  wage_eur                    | 8000.0
#  age                         | 22
#  dob                         | 1992-04-16
#  height_cm                   | 184
#  weight_kg                   | 76
#  club_team_id                | 1013.0
#  club_name                   | San Lorenzo de Al...
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 19
#  club_loaned_from            | NULL
#  club_joined                 | 2011-08-01
#  club_contract_valid_until   | 2016
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 2
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | NULL
#  player_tags                 | NULL
#  player_traits               | NULL
#  pace                        | 51
#  shooting                    | 61
#  passing                     | 69
#  dribbling                   | 70
#  defending                   | 60
#  physic                      | 60
#  attacking_crossing          | 67
#  attacking_finishing         | 56
#  attacking_heading_accuracy  | 59
#  attacking_short_passing     | 69
#  attacking_volleys           | 54
#  skill_dribbling             | 70
#  skill_curve                 | 79
#  skill_fk_accuracy           | 79
#  skill_long_passing          | 70
#  skill_ball_control          | 71
#  movement_acceleration       | 52
#  movement_sprint_speed       | 50
#  movement_agility            | 75
#  movement_reactions          | 67
#  movement_balance            | 59
#  power_shot_power            | 74
#  power_jumping               | 45
#  power_stamina               | 48
#  power_strength              | 69
#  power_long_shots            | 63
#  mentality_aggression        | 56
#  mentality_interceptions     | 63
#  mentality_positioning       | 64
#  mentality_vision            | 65
#  mentality_penalties         | 55
#  mentality_composure         | NULL
#  defending_marking_awareness | 59
#  defending_standing_tackle   | 61
#  defending_sliding_tackle    | 51
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 14
#  goalkeeping_kicking         | 11
#  goalkeeping_positioning     | 11
#  goalkeeping_reflexes        | 6
#  goalkeeping_speed           | NULL
#  ls                          | 63
#  st                          | 63
#  rs                          | 63
#  lw                          | 66
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 66
#  lam                         | 67
#  cam                         | 67
#  ram                         | 67
#  lm                          | 66
#  lcm                         | 66
#  cm                          | 66
#  rcm                         | 66
#  rm                          | 66
#  lwb                         | 62
#  ldm                         | 64
#  cdm                         | 64
#  rdm                         | 64
#  rwb                         | 62
#  lb                          | 60
#  lcb                         | 60
#  cb                          | 60
#  rcb                         | 60
#  rb                          | 60
#  gk                          | 15
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  gender                      | male
# -RECORD 2-------------------------------------------
#  sofifa_id                   | 215128
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Monje
#  long_name                   | Leonardo Monje
#  player_positions            | LW
#  overall                     | 66
#  potential                   | 66
#  value_eur                   | 400000.0
#  wage_eur                    | 2000.0
#  age                         | 33
#  dob                         | 1981-03-16
#  height_cm                   | 165
#  weight_kg                   | 65
#  club_team_id                | 112534.0
#  club_name                   | CD Universidad de...
#  league_name                 | Chilian Campeonat...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 19
#  club_loaned_from            | NULL
#  club_joined                 | 2013-12-26
#  club_contract_valid_until   | 2015
#  nationality_id              | 55
#  nationality_name            | Chile
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Stocky (170-)
#  real_face                   | No
#  release_clause_eur          | NULL
#  player_tags                 | NULL
#  player_traits               | Speed Dribbler (AI)
#  pace                        | 84
#  shooting                    | 63
#  passing                     | 61
#  dribbling                   | 69
#  defending                   | 31
#  physic                      | 54
#  attacking_crossing          | 56
#  attacking_finishing         | 61
#  attacking_heading_accuracy  | 63
#  attacking_short_passing     | 64
#  attacking_volleys           | 59
#  skill_dribbling             | 66
#  skill_curve                 | 49
#  skill_fk_accuracy           | 72
#  skill_long_passing          | 49
#  skill_ball_control          | 70
#  movement_acceleration       | 86
#  movement_sprint_speed       | 82
#  movement_agility            | 74
#  movement_reactions          | 53
#  movement_balance            | 91
#  power_shot_power            | 67
#  power_jumping               | 60
#  power_stamina               | 76
#  power_strength              | 43
#  power_long_shots            | 60
#  mentality_aggression        | 54
#  mentality_interceptions     | 35
#  mentality_positioning       | 64
#  mentality_vision            | 72
#  mentality_penalties         | 71
#  mentality_composure         | NULL
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 25
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 11
#  goalkeeping_handling        | 13
#  goalkeeping_kicking         | 12
#  goalkeeping_positioning     | 8
#  goalkeeping_reflexes        | 12
#  goalkeeping_speed           | NULL
#  ls                          | 64
#  st                          | 64
#  rs                          | 64
#  lw                          | 66
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 66
#  lam                         | 66
#  cam                         | 66
#  ram                         | 66
#  lm                          | 65
#  lcm                         | 59
#  cm                          | 59
#  rcm                         | 59
#  rm                          | 65
#  lwb                         | 50
#  ldm                         | 50
#  cdm                         | 50
#  rdm                         | 50
#  rwb                         | 50
#  lb                          | 47
#  lcb                         | 41
#  cb                          | 41
#  rcb                         | 41
#  rb                          | 47
#  gk                          | 14
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  gender                      | male
# -RECORD 3-------------------------------------------
#  sofifa_id                   | 215130
#  player_url                  | https://sofifa.co...
#  short_name                  | N. Ibáñez
#  long_name                   | Nelson Martín Ibáñez
#  player_positions            | GK
#  overall                     | 66
#  potential                   | 66
#  value_eur                   | 575000.0
#  wage_eur                    | 9000.0
#  age                         | 32
#  dob                         | 1981-11-13
#  height_cm                   | 187
#  weight_kg                   | 89
#  club_team_id                | 101085.0
#  club_name                   | Racing Club
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 21
#  club_loaned_from            | NULL
#  club_joined                 | 2013-07-24
#  club_contract_valid_until   | 2020
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | NULL
#  player_tags                 | NULL
#  player_traits               | NULL
#  pace                        | NULL
#  shooting                    | NULL
#  passing                     | NULL
#  dribbling                   | NULL
#  defending                   | NULL
#  physic                      | NULL
#  attacking_crossing          | 25
#  attacking_finishing         | 25
#  attacking_heading_accuracy  | 25
#  attacking_short_passing     | 22
#  attacking_volleys           | 25
#  skill_dribbling             | 25
#  skill_curve                 | 25
#  skill_fk_accuracy           | 25
#  skill_long_passing          | 23
#  skill_ball_control          | 26
#  movement_acceleration       | 46
#  movement_sprint_speed       | 44
#  movement_agility            | 38
#  movement_reactions          | 55
#  movement_balance            | 55
#  power_shot_power            | 20
#  power_jumping               | 51
#  power_stamina               | 37
#  power_strength              | 65
#  power_long_shots            | 25
#  mentality_aggression        | 31
#  mentality_interceptions     | 25
#  mentality_positioning       | 25
#  mentality_vision            | 25
#  mentality_penalties         | 22
#  mentality_composure         | NULL
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 25
#  defending_sliding_tackle    | 25
#  goalkeeping_diving          | 73
#  goalkeeping_handling        | 56
#  goalkeeping_kicking         | 59
#  goalkeeping_positioning     | 68
#  goalkeeping_reflexes        | 72
#  goalkeeping_speed           | 45
#  ls                          | 31
#  st                          | 31
#  rs                          | 31
#  lw                          | 30
#  lf                          | 29
#  cf                          | 29
#  rf                          | 29
#  rw                          | 30
#  lam                         | 28
#  cam                         | 28
#  ram                         | 28
#  lm                          | 30
#  lcm                         | 28
#  cm                          | 28
#  rcm                         | 28
#  rm                          | 30
#  lwb                         | 29
#  ldm                         | 31
#  cdm                         | 31
#  rdm                         | 31
#  rwb                         | 29
#  lb                          | 30
#  lcb                         | 32
#  cb                          | 32
#  rcb                         | 32
#  rb                          | 30
#  gk                          | 66
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  gender                      | male
# -RECORD 4-------------------------------------------
#  sofifa_id                   | 215182
#  player_url                  | https://sofifa.co...
#  short_name                  | I. Bella
#  long_name                   | Iván Gonzalo Bella
#  player_positions            | LM, RM
#  overall                     | 66
#  potential                   | 70
#  value_eur                   | 725000.0
#  wage_eur                    | 6000.0
#  age                         | 24
#  dob                         | 1989-09-13
#  height_cm                   | 179
#  weight_kg                   | 71
#  club_team_id                | 110395.0
#  club_name                   | Club Atlético Lanús
#  league_name                 | Argentina Primera...
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 24
#  club_loaned_from            | NULL
#  club_joined                 | 2014-07-08
#  club_contract_valid_until   | 2015
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | NULL
#  nation_position             | NULL
#  nation_jersey_number        | NULL
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 1
#  work_rate                   | Medium/Low
#  body_type                   | Lean (170-185)
#  real_face                   | No
#  release_clause_eur          | NULL
#  player_tags                 | NULL
#  player_traits               | Speed Dribbler (AI)
#  pace                        | 77
#  shooting                    | 60
#  passing                     | 62
#  dribbling                   | 70
#  defending                   | 35
#  physic                      | 62
#  attacking_crossing          | 67
#  attacking_finishing         | 57
#  attacking_heading_accuracy  | 54
#  attacking_short_passing     | 62
#  attacking_volleys           | 55
#  skill_dribbling             | 70
#  skill_curve                 | 68
#  skill_fk_accuracy           | 56
#  skill_long_passing          | 57
#  skill_ball_control          | 69
#  movement_acceleration       | 76
#  movement_sprint_speed       | 78
#  movement_agility            | 77
#  movement_reactions          | 64
#  movement_balance            | 75
#  power_shot_power            | 71
#  power_jumping               | 71
#  power_stamina               | 65
#  power_strength              | 57
#  power_long_shots            | 60
#  mentality_aggression        | 70
#  mentality_interceptions     | 42
#  mentality_positioning       | 60
#  mentality_vision            | 63
#  mentality_penalties         | 52
#  mentality_composure         | NULL
#  defending_marking_awareness | 32
#  defending_standing_tackle   | 30
#  defending_sliding_tackle    | 27
#  goalkeeping_diving          | 15
#  goalkeeping_handling        | 6
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 10
#  goalkeeping_reflexes        | 10
#  goalkeeping_speed           | NULL
#  ls                          | 63
#  st                          | 63
#  rs                          | 63
#  lw                          | 67
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 67
#  lam                         | 65
#  cam                         | 65
#  ram                         | 65
#  lm                          | 66
#  lcm                         | 59
#  cm                          | 59
#  rcm                         | 59
#  rm                          | 66
#  lwb                         | 54
#  ldm                         | 54
#  cdm                         | 54
#  rdm                         | 54
#  rwb                         | 54
#  lb                          | 50
#  lcb                         | 46
#  cb                          | 46
#  rcb                         | 46
#  rb                          | 50
#  gk                          | 14
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | NULL
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 2015
#  gender                      | male
# only showing top 5 rows

# %%
data_postgres.tail(5)
# Out:
# [Row(sofifa_id=264232, player_url='https://sofifa.com/player/264232/abdulkareem-al-sultan/220002', short_name='A. Al Sultan', long_name='Abdulkareem Al Sultan', player_positions='CB', overall=52, potential=63, value_eur=170000.0, wage_eur=2000.0, age=21, dob=datetime.date(2000, 6, 24), height_cm=186, weight_kg=76, club_team_id=112572.0, club_name='Al Tai', league_name='Saudi Abdul L. Jameel League', league_level=1, club_position='RES', club_jersey_number=4, club_loaned_from=None, club_joined=datetime.date(2020, 8, 1), club_contract_valid_until=2025, nationality_id=183, nationality_name='Saudi Arabia', nation_team_id=None, nation_position=None, nation_jersey_number=None, preferred_foot='Right', weak_foot=3, skill_moves=2, international_reputation=1, work_rate='Medium/Medium', body_type='Lean (185+)', real_face='No', release_clause_eur='315000', player_tags=None, player_traits=None, pace=59, shooting=25, passing=38, dribbling=38, defending=53, physic=59, attacking_crossing=39, attacking_finishing=21, attacking_heading_accuracy=51, attacking_short_passing=46, attacking_volleys=24, skill_dribbling=32, skill_curve=29, skill_fk_accuracy=24, skill_long_passing=38, skill_ball_control=38, movement_acceleration=60, movement_sprint_speed=58, movement_agility=52, movement_reactions=49, movement_balance=57, power_shot_power=30, power_jumping=66, power_stamina=62, power_strength=60, power_long_shots=25, mentality_aggression=49, mentality_interceptions=53, mentality_positioning=25, mentality_vision=30, mentality_penalties=33, mentality_composure='38', defending_marking_awareness=52, defending_standing_tackle=54, defending_sliding_tackle=51, goalkeeping_diving=8, goalkeeping_handling=11, goalkeeping_kicking=10, goalkeeping_positioning=9, goalkeeping_reflexes=12, goalkeeping_speed=None, ls='37+2', st='37+2', rs='37+2', lw='38', lf='36', cf='36', rf='36', rw='38', lam='37+2', cam='37+2', ram='37+2', lm='40+2', lcm='40+2', cm='40+2', rcm='40+2', rm='40+2', lwb='50+2', ldm='48+2', cdm='48+2', rdm='48+2', rwb='50+2', lb='51+2', lcb='52+2', cb='52+2', rcb='52+2', rb='51+2', gk='14+2', player_face_url='https://cdn.sofifa.net/players/264/232/22_120.png', club_logo_url='https://cdn.sofifa.net/teams/112572/60.png', club_flag_url='https://cdn.sofifa.net/flags/sa.png', nation_logo_url=None, nation_flag_url='https://cdn.sofifa.net/flags/sa.png', year=2022, gender='female'),
#  Row(sofifa_id=264271, player_url='https://sofifa.com/player/264271/mohammed-marzouq/220002', short_name='M. Marzouq', long_name='Mohammed Marzouq', player_positions='LB, CDM', overall=52, potential=66, value_eur=180000.0, wage_eur=1000.0, age=19, dob=datetime.date(2001, 8, 14), height_cm=173, weight_kg=68, club_team_id=112572.0, club_name='Al Tai', league_name='Saudi Abdul L. Jameel League', league_level=1, club_position='RES', club_jersey_number=87, club_loaned_from=None, club_joined=datetime.date(2021, 8, 2), club_contract_valid_until=2025, nationality_id=183, nationality_name='Saudi Arabia', nation_team_id=None, nation_position=None, nation_jersey_number=None, preferred_foot='Left', weak_foot=3, skill_moves=2, international_reputation=1, work_rate='Medium/Medium', body_type='Lean (170-185)', real_face='No', release_clause_eur='410000', player_tags=None, player_traits=None, pace=62, shooting=31, passing=44, dribbling=49, defending=49, physic=50, attacking_crossing=45, attacking_finishing=27, attacking_heading_accuracy=45, attacking_short_passing=48, attacking_volleys=24, skill_dribbling=47, skill_curve=32, skill_fk_accuracy=33, skill_long_passing=44, skill_ball_control=49, movement_acceleration=62, movement_sprint_speed=62, movement_agility=57, movement_reactions=46, movement_balance=70, power_shot_power=35, power_jumping=62, power_stamina=53, power_strength=49, power_long_shots=33, mentality_aggression=47, mentality_interceptions=50, mentality_positioning=41, mentality_vision=43, mentality_penalties=35, mentality_composure='39', defending_marking_awareness=47, defending_standing_tackle=51, defending_sliding_tackle=50, goalkeeping_diving=14, goalkeeping_handling=8, goalkeeping_kicking=9, goalkeeping_positioning=11, goalkeeping_reflexes=9, goalkeeping_speed=None, ls='42+2', st='42+2', rs='42+2', lw='46', lf='44', cf='44', rf='44', rw='46', lam='45+2', cam='45+2', ram='45+2', lm='47+2', lcm='46+2', cm='46+2', rcm='46+2', rm='47+2', lwb='50+2', ldm='48+2', cdm='48+2', rdm='48+2', rwb='50+2', lb='50+2', lcb='49+2', cb='49+2', rcb='49+2', rb='50+2', gk='14+2', player_face_url='https://cdn.sofifa.net/players/264/271/22_120.png', club_logo_url='https://cdn.sofifa.net/teams/112572/60.png', club_flag_url='https://cdn.sofifa.net/flags/sa.png', nation_logo_url=None, nation_flag_url='https://cdn.sofifa.net/flags/sa.png', year=2022, gender='female'),
#  Row(sofifa_id=264282, player_url='https://sofifa.com/player/264282/kacper-danielewicz/220002', short_name='K. Danielewicz', long_name='Kacper Danielewicz', player_positions='GK', overall=52, potential=67, value_eur=160000.0, wage_eur=500.0, age=17, dob=datetime.date(2004, 1, 11), height_cm=185, weight_kg=75, club_team_id=1920.0, club_name='Oldham Athletic', league_name='English League Two', league_level=4, club_position='RES', club_jersey_number=13, club_loaned_from=None, club_joined=datetime.date(2020, 7, 1), club_contract_valid_until=2022, nationality_id=37, nationality_name='Poland', nation_team_id=None, nation_position=None, nation_jersey_number=None, preferred_foot='Right', weak_foot=2, skill_moves=1, international_reputation=1, work_rate='Medium/Medium', body_type='Lean (185+)', real_face='No', release_clause_eur='380000', player_tags=None, player_traits=None, pace=None, shooting=None, passing=None, dribbling=None, defending=None, physic=None, attacking_crossing=11, attacking_finishing=6, attacking_heading_accuracy=12, attacking_short_passing=29, attacking_volleys=6, skill_dribbling=9, skill_curve=11, skill_fk_accuracy=14, skill_long_passing=21, skill_ball_control=11, movement_acceleration=25, movement_sprint_speed=16, movement_agility=36, movement_reactions=38, movement_balance=41, power_shot_power=39, power_jumping=64, power_stamina=18, power_strength=38, power_long_shots=9, mentality_aggression=20, mentality_interceptions=7, mentality_positioning=7, mentality_vision=36, mentality_penalties=14, mentality_composure='29', defending_marking_awareness=5, defending_standing_tackle=12, defending_sliding_tackle=11, goalkeeping_diving=56, goalkeeping_handling=51, goalkeeping_kicking=52, goalkeeping_positioning=51, goalkeeping_reflexes=52, goalkeeping_speed=21, ls='17+2', st='17+2', rs='17+2', lw='17', lf='18', cf='18', rf='18', rw='17', lam='20+2', cam='20+2', ram='20+2', lm='18+2', lcm='20+2', cm='20+2', rcm='20+2', rm='18+2', lwb='16+2', ldm='18+2', cdm='18+2', rdm='18+2', rwb='16+2', lb='15+2', lcb='17+2', cb='17+2', rcb='17+2', rb='15+2', gk='51+2', player_face_url='https://cdn.sofifa.net/players/264/282/22_120.png', club_logo_url='https://cdn.sofifa.net/teams/1920/60.png', club_flag_url='https://cdn.sofifa.net/flags/gb-eng.png', nation_logo_url=None, nation_flag_url='https://cdn.sofifa.net/flags/pl.png', year=2022, gender='female'),
#  Row(sofifa_id=264296, player_url='https://sofifa.com/player/264296/kristoffer-harrison/220002', short_name='K. Harrison', long_name='Kristoffer Harrison', player_positions='CB', overall=52, potential=67, value_eur=180000.0, wage_eur=500.0, age=19, dob=datetime.date(2002, 1, 25), height_cm=183, weight_kg=73, club_team_id=917.0, club_name='Stabæk Fotball', league_name='Norwegian Eliteserien', league_level=1, club_position='RES', club_jersey_number=29, club_loaned_from=None, club_joined=datetime.date(2021, 7, 21), club_contract_valid_until=2025, nationality_id=36, nationality_name='Norway', nation_team_id=None, nation_position=None, nation_jersey_number=None, preferred_foot='Right', weak_foot=2, skill_moves=2, international_reputation=1, work_rate='High/Medium', body_type='Normal (170-185)', real_face='No', release_clause_eur='338000', player_tags=None, player_traits=None, pace=60, shooting=48, passing=42, dribbling=49, defending=52, physic=56, attacking_crossing=42, attacking_finishing=50, attacking_heading_accuracy=49, attacking_short_passing=40, attacking_volleys=33, skill_dribbling=48, skill_curve=46, skill_fk_accuracy=35, skill_long_passing=43, skill_ball_control=49, movement_acceleration=61, movement_sprint_speed=60, movement_agility=47, movement_reactions=45, movement_balance=62, power_shot_power=49, power_jumping=74, power_stamina=63, power_strength=53, power_long_shots=46, mentality_aggression=48, mentality_interceptions=52, mentality_positioning=52, mentality_vision=47, mentality_penalties=40, mentality_composure='43', defending_marking_awareness=50, defending_standing_tackle=54, defending_sliding_tackle=54, goalkeeping_diving=6, goalkeeping_handling=7, goalkeeping_kicking=12, goalkeeping_positioning=9, goalkeeping_reflexes=6, goalkeeping_speed=None, ls='50+2', st='50+2', rs='50+2', lw='49', lf='49', cf='49', rf='49', rw='49', lam='48+2', cam='48+2', ram='48+2', lm='49+2', lcm='47+2', cm='47+2', rcm='47+2', rm='49+2', lwb='51+2', ldm='49+2', cdm='49+2', rdm='49+2', rwb='51+2', lb='52+2', lcb='52+2', cb='52+2', rcb='52+2', rb='52+2', gk='11+2', player_face_url='https://cdn.sofifa.net/players/264/296/22_120.png', club_logo_url='https://cdn.sofifa.net/teams/917/60.png', club_flag_url='https://cdn.sofifa.net/flags/no.png', nation_logo_url=None, nation_flag_url='https://cdn.sofifa.net/flags/no.png', year=2022, gender='female'),
#  Row(sofifa_id=264354, player_url='https://sofifa.com/player/264354/olivier-sukiennicki/220002', short_name='O. Sukiennicki', long_name='Olivier Sukiennicki', player_positions='CM', overall=52, potential=68, value_eur=200000.0, wage_eur=1000.0, age=18, dob=datetime.date(2003, 5, 25), height_cm=172, weight_kg=70, club_team_id=1804.0, club_name='Bradford City', league_name='English League Two', league_level=4, club_position='RES', club_jersey_number=32, club_loaned_from=None, club_joined=datetime.date(2021, 8, 4), club_contract_valid_until=2022, nationality_id=37, nationality_name='Poland', nation_team_id=None, nation_position=None, nation_jersey_number=None, preferred_foot='Right', weak_foot=3, skill_moves=3, international_reputation=1, work_rate='Medium/Medium', body_type='Lean (170-185)', real_face='No', release_clause_eur='475000', player_tags=None, player_traits='Flair, Technical Dribbler (AI)', pace=71, shooting=47, passing=50, dribbling=58, defending=45, physic=43, attacking_crossing=39, attacking_finishing=44, attacking_heading_accuracy=40, attacking_short_passing=54, attacking_volleys=44, skill_dribbling=57, skill_curve=48, skill_fk_accuracy=43, skill_long_passing=53, skill_ball_control=55, movement_acceleration=72, movement_sprint_speed=71, movement_agility=72, movement_reactions=52, movement_balance=77, power_shot_power=52, power_jumping=51, power_stamina=40, power_strength=46, power_long_shots=50, mentality_aggression=37, mentality_interceptions=45, mentality_positioning=47, mentality_vision=54, mentality_penalties=47, mentality_composure='52', defending_marking_awareness=42, defending_standing_tackle=49, defending_sliding_tackle=42, goalkeeping_diving=14, goalkeeping_handling=10, goalkeeping_kicking=11, goalkeeping_positioning=11, goalkeeping_reflexes=14, goalkeeping_speed=None, ls='51+2', st='51+2', rs='51+2', lw='54', lf='54', cf='54', rf='54', rw='54', lam='55+2', cam='55+2', ram='55+2', lm='53+2', lcm='52+2', cm='52+2', rcm='52+2', rm='53+2', lwb='49+2', ldm='48+2', cdm='48+2', rdm='48+2', rwb='49+2', lb='49+2', lcb='46+2', cb='46+2', rcb='46+2', rb='49+2', gk='17+2', player_face_url='https://cdn.sofifa.net/players/264/354/22_120.png', club_logo_url='https://cdn.sofifa.net/teams/1804/60.png', club_flag_url='https://cdn.sofifa.net/flags/gb-eng.png', nation_logo_url=None, nation_flag_url='https://cdn.sofifa.net/flags/pl.png', year=2022, gender='female')]
